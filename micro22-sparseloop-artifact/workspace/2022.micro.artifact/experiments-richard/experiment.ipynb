# %%
from helpers import *
import os
print(os.getcwd())
# Out:
# /home/workspace/2022.micro.artifact/experiments-richard

# %%
test_run("1dconv_input0.001_weight0.001.yaml")
# Out:
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.001_weight0.001.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.12 | pJ/Algorithmic-Compute =    0.003 | pJ/Compute = 1645.117 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.12 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  238.119 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5634 fanout, 4366 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:46:45,072 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:46:45,133 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:46:45,136 - timeloop_mapper - WARNING - No energy reference file found
# Summary stats for best mapping found by mapper:
#   Utilization = 0.12 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  238.119
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.001_weight0.001.yaml 1dconv_input0.001_weight0.001/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input0.001_weight0.001
# Timeloop completed successfully.
# <class 'dict'>
# {'MAC': {'energy': 21.20526, 'utilization': 0.125}, 'reg': {'energy': 100.63347867298289, 'storage_access_energy': 100.63347867298289, 'read_energy': 80.50678293838631, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.       , 0.0021327, 2.       ]), 'utilization': 0.00013329383886255541, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'psum_spad': {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'weight_spad': {'energy': 253.77035999999998, 'storage_access_energy': 253.77035999999998, 'read_energy': 253.77035999999998, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([126.88518,       nan,   0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'iact_spad': {'energy': 78.2236, 'storage_access_energy': 78.2236, 'read_energy': 78.2236, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([  0, 140,   0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([  0, 140,   0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'BackingStorage': {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}}
# MAC
#
#
#
# {'energy': 21.20526, 'utilization': 0.125}
# reg
#
#
#
# {'energy': 100.63347867298289, 'storage_access_energy': 100.63347867298289, 'read_energy': 80.50678293838631, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.       , 0.0021327, 2.       ]), 'utilization': 0.00013329383886255541, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 253.77035999999998, 'storage_access_energy': 253.77035999999998, 'read_energy': 253.77035999999998, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([126.88518,       nan,   0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 78.2236, 'storage_access_energy': 78.2236, 'read_energy': 78.2236, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([  0, 140,   0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([  0, 140,   0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}

# %%
test_run("1dconv_input0.01_weight0.01.yaml")
# Out:
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.01_weight0.01.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 8568
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 126
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 5713073856
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 1428268464 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  2] STATEMENT: 10000 invalid mappings (6410 fanout, 3590 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (6401 fanout, 3599 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (6411 fanout, 3589 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 10000 invalid mappings (6410 fanout, 3590 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:42:25,224 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:42:25,225 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:42:25,226 - timeloop_mapper - WARNING - No energy reference file found
# MESSAGE: no valid mappings found within search criteria. Some suggestions:
# (1) Observe each mapper thread's termination message. If it terminated due to
#     consecutive failed mappings, it will tell you the number of mappings that
#     failed because of a spatial fanout violation and the number that failed
#     because of a buffer capacity violation.
# (2) Check your architecture configuration (especially mapspace constraints).
#     Try to find the offending constraints that are likely to have caused the
#     above violations, and disable those constraints.
# (3) Try other search algorithms, and relax the termination criteria:
#     victory-condition, timeout and/or search-size.
# (4) Enable mapper's diagnostics (mapper.diagnostics = True) to track and emit
#     more information about failed mappings.
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.01_weight0.01.yaml 1dconv_input0.01_weight0.01/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input0.01_weight0.01
# Timeloop failed!
# ERROR: key not found: mapping, at line: 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 test_run("1dconv_input0.01_weight0.01.yaml")
#
# File ~/2022.micro.artifact/experiments-richard/helpers.py:446, in test_run(workload_path)
#     433 output_path = run_timeloop(
#     434     arch_yaml=architecture,
#     435     sparse_opts=sparse_opts,
#    (...)
#     442     output_dir=out_path
#     443 )
#     445 # # Test plotting functions
# --> 446 output = parse_timeloop_stats(out_path + "/timeloop-model.map+stats.xml")
#     447 plot_read_write_energy(output["energy_breakdown_pJ"])
#
# File ~/2022.micro.artifact/experiments-richard/parse_timeloop_output.py:58, in parse_timeloop_stats(filename)
#      56 if (os.path.isdir(filename)):
#      57     filename = os.path.join(filename, xml_file_name)
# ---> 58 tree = ET.parse(filename)
#      59 root = tree.getroot()
#      61 # Parse out the problem shape
#
# File /usr/local/bin/conda/lib/python3.8/xml/etree/ElementTree.py:1202, in parse(source, parser)
#    1193 """Parse XML document into element tree.
#    1194
#    1195 *source* is a filename or file object containing XML data,
#    (...)
#    1199
#    1200 """
#    1201 tree = ElementTree()
# -> 1202 tree.parse(source, parser)
#    1203 return tree
#
# File /usr/local/bin/conda/lib/python3.8/xml/etree/ElementTree.py:584, in ElementTree.parse(self, source, parser)
#     582 close_source = False
#     583 if not hasattr(source, "read"):
# --> 584     source = open(source, "rb")
#     585     close_source = True
#     586 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '1dconv_input0.01_weight0.01/timeloop-model.map+stats.xml'

# %%
from concurrent.futures import ThreadPoolExecutor  # or use ProcessPoolExecutor
# from concurrent.futures import ProcessPoolExecutor

densities = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.5, 1.0]

# Generate file names
names = [
    f"1dconv_input{str(d1)}_weight{str(d1)}.yaml"
    for d1 in densities
]

# Run in parallel
for name in names:
    test_run(name)
# Out:
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.0001_weight0.0001.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.06 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  419.973 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.06 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =   77.852 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5541 fanout, 4459 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:48:45,347 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:48:45,355 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:48:45,357 - timeloop_mapper - WARNING - No energy reference file found
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =   77.852
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.0001_weight0.0001.yaml 1dconv_input0.0001_weight0.0001/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input0.0001_weight0.0001
# Timeloop completed successfully.
# <class 'dict'>
# {'MAC': {'energy': 2.79032, 'utilization': 0.125}, 'reg': {'energy': 11.18149763032794, 'storage_access_energy': 11.18149763032794, 'read_energy': 8.945198104262351, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.00000000e+00, 2.36966825e-04, 2.00000000e+00]), 'utilization': 1.4810426540279309e-05, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'psum_spad': {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'weight_spad': {'energy': 32.53516, 'storage_access_energy': 32.53516, 'read_energy': 32.53516, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([16.26758,      nan,  0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'iact_spad': {'energy': 8.93984, 'storage_access_energy': 8.93984, 'read_energy': 8.93984, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([ 0, 16,  0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([ 0, 16,  0]), 'instances': array([0., 2., 0.]), 'utilization': 0.0078125, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'BackingStorage': {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}}
# MAC
#
#
#
# {'energy': 2.79032, 'utilization': 0.125}
# reg
#
#
#
# {'energy': 11.18149763032794, 'storage_access_energy': 11.18149763032794, 'read_energy': 8.945198104262351, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.00000000e+00, 2.36966825e-04, 2.00000000e+00]), 'utilization': 1.4810426540279309e-05, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 32.53516, 'storage_access_energy': 32.53516, 'read_energy': 32.53516, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([16.26758,      nan,  0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 8.93984, 'storage_access_energy': 8.93984, 'read_energy': 8.93984, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([ 0, 16,  0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([ 0, 16,  0]), 'instances': array([0., 2., 0.]), 'utilization': 0.0078125, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.0005_weight0.0005.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.06 | pJ/Algorithmic-Compute =    0.002 | pJ/Compute = 1729.915 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.06 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  265.330 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5634 fanout, 4366 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:48:49,056 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:48:49,061 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:48:49,064 - timeloop_mapper - WARNING - No energy reference file found
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  265.330
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.0005_weight0.0005.yaml 1dconv_input0.0005_weight0.0005/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input0.0005_weight0.0005
# Timeloop completed successfully.
# <class 'dict'>
# {'MAC': {'energy': 11.72638, 'utilization': 0.125}, 'reg': {'energy': 55.90748815166065, 'storage_access_energy': 55.90748815166065, 'read_energy': 44.72599052132852, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.00000000e+00, 1.18483412e-03, 2.00000000e+00]), 'utilization': 7.40521327014243e-05, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'psum_spad': {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'weight_spad': {'energy': 131.70955999999998, 'storage_access_energy': 131.70955999999998, 'read_energy': 131.70955999999998, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([65.85478,      nan,  0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'iact_spad': {'energy': 43.581720000000004, 'storage_access_energy': 43.581720000000004, 'read_energy': 43.581720000000004, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([ 0, 78,  0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([ 0, 78,  0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'BackingStorage': {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}}
# MAC
#
#
#
# {'energy': 11.72638, 'utilization': 0.125}
# reg
#
#
#
# {'energy': 55.90748815166065, 'storage_access_energy': 55.90748815166065, 'read_energy': 44.72599052132852, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.00000000e+00, 1.18483412e-03, 2.00000000e+00]), 'utilization': 7.40521327014243e-05, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 131.70955999999998, 'storage_access_energy': 131.70955999999998, 'read_energy': 131.70955999999998, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([65.85478,      nan,  0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 43.581720000000004, 'storage_access_energy': 43.581720000000004, 'read_energy': 43.581720000000004, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([ 0, 78,  0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([ 0, 78,  0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.001_weight0.001.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.12 | pJ/Algorithmic-Compute =    0.003 | pJ/Compute = 1645.117 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.12 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  238.119 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5634 fanout, 4366 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:48:52,853 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:48:52,860 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:48:52,862 - timeloop_mapper - WARNING - No energy reference file found
# Summary stats for best mapping found by mapper:
#   Utilization = 0.12 | pJ/Algorithmic-Compute =    0.000 | pJ/Compute =  238.119
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.001_weight0.001.yaml 1dconv_input0.001_weight0.001/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input0.001_weight0.001
# Timeloop completed successfully.
# <class 'dict'>
# {'MAC': {'energy': 21.20526, 'utilization': 0.125}, 'reg': {'energy': 100.63347867298289, 'storage_access_energy': 100.63347867298289, 'read_energy': 80.50678293838631, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.       , 0.0021327, 2.       ]), 'utilization': 0.00013329383886255541, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'psum_spad': {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'weight_spad': {'energy': 253.77035999999998, 'storage_access_energy': 253.77035999999998, 'read_energy': 253.77035999999998, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([126.88518,       nan,   0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'iact_spad': {'energy': 78.2236, 'storage_access_energy': 78.2236, 'read_energy': 78.2236, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([  0, 140,   0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([  0, 140,   0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'BackingStorage': {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}}
# MAC
#
#
#
# {'energy': 21.20526, 'utilization': 0.125}
# reg
#
#
#
# {'energy': 100.63347867298289, 'storage_access_energy': 100.63347867298289, 'read_energy': 80.50678293838631, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.       , 0.0021327, 2.       ]), 'utilization': 0.00013329383886255541, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 22.40508, 'storage_access_energy': 22.40508, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([     nan,      nan, 11.20254]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 1]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 1]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 253.77035999999998, 'storage_access_energy': 253.77035999999998, 'read_energy': 253.77035999999998, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([126.88518,       nan,   0.     ]), 'actual_reads_per_instance': array([1, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([1, 0, 0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 78.2236, 'storage_access_energy': 78.2236, 'read_energy': 78.2236, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([  0, 140,   0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([  0, 140,   0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.005_weight0.005.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.25 | pJ/Algorithmic-Compute =    0.015 | pJ/Compute =  575.529 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.12 | pJ/Algorithmic-Compute =    0.002 | pJ/Compute =   81.665 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5634 fanout, 4366 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:48:53,620 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:48:53,626 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:48:53,628 - timeloop_mapper - WARNING - No energy reference file found
# Summary stats for best mapping found by mapper:
#   Utilization = 0.12 | pJ/Algorithmic-Compute =    0.002 | pJ/Compute =   81.665
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.005_weight0.005.yaml 1dconv_input0.005_weight0.005/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input0.005_weight0.005
# Timeloop completed successfully.
# <class 'dict'>
# {'MAC': {'energy': 111.28407999999999, 'utilization': 0.125}, 'reg': {'energy': 480.804398104269, 'storage_access_energy': 480.804398104269, 'read_energy': 384.6435184834152, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.        , 0.01018957, 2.        ]), 'utilization': 0.0006368483412322323, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'psum_spad': {'energy': 55.25113999999999, 'storage_access_energy': 55.25113999999999, 'read_energy': 26.602400740740737, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([       nan,        nan, 1.02316926]), 'actual_reads_per_instance': array([ 0,  0, 13]), 'actual_updates_per_instance': array([ 0,  0, 14]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([ 0,  0, 27]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'weight_spad': {'energy': 1266.0528, 'storage_access_energy': 1266.0528, 'read_energy': 1266.0528, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([45.21617143,         nan,  0.        ]), 'actual_reads_per_instance': array([14,  0,  0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([14,  0,  0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'iact_spad': {'energy': 373.23832, 'storage_access_energy': 373.23832, 'read_energy': 373.23832, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([  0, 668,   0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([  0, 668,   0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'BackingStorage': {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}}
# MAC
#
#
#
# {'energy': 111.28407999999999, 'utilization': 0.125}
# reg
#
#
#
# {'energy': 480.804398104269, 'storage_access_energy': 480.804398104269, 'read_energy': 384.6435184834152, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 524288,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 131072,      0]), 'actual_accesses_per_instance': array([     0, 655360,      0]), 'instances': array([2.        , 0.01018957, 2.        ]), 'utilization': 0.0006368483412322323, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 55.25113999999999, 'storage_access_energy': 55.25113999999999, 'read_energy': 26.602400740740737, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([       nan,        nan, 1.02316926]), 'actual_reads_per_instance': array([ 0,  0, 13]), 'actual_updates_per_instance': array([ 0,  0, 14]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([ 0,  0, 27]), 'instances': array([2., 2., 2.]), 'utilization': 0.015625, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 1266.0528, 'storage_access_energy': 1266.0528, 'read_energy': 1266.0528, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([45.21617143,         nan,  0.        ]), 'actual_reads_per_instance': array([14,  0,  0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([14,  0,  0]), 'instances': array([2., 2., 0.]), 'utilization': 0.0026041666666666665, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 373.23832, 'storage_access_energy': 373.23832, 'read_energy': 373.23832, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([  0, 668,   0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([  0, 668,   0]), 'instances': array([0., 2., 0.]), 'utilization': 0.015625, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input0.01_weight0.01.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.25 | pJ/Algorithmic-Compute =    0.031 | pJ/Compute =  302.697 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.12 | pJ/Algorithmic-Compute =    0.004 | pJ/Compute =   43.863 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5634 fanout, 4366 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:48:54,400 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:48:54,406 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:48:54,409 - timeloop_mapper - WARNING - No energy reference file found
# ...
# MAC
#
#
#
# {'energy': 151723.70432, 'utilization': 0.25}
# reg
#
#
#
# {'energy': 75497.472, 'storage_access_energy': 75497.472, 'read_energy': 37748.736, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 262144,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 262144,      0]), 'actual_accesses_per_instance': array([     0, 524288,      0]), 'instances': array([4., 2., 4.]), 'utilization': 0.125, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 331120.31103999994, 'storage_access_energy': 331120.31103999994, 'read_energy': 165519.72568959216, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([      nan,       nan, 0.6317161]), 'actual_reads_per_instance': array([    0,     0, 65504]), 'actual_updates_per_instance': array([    0,     0, 65536]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([     0,      0, 131040]), 'instances': array([4., 4., 4.]), 'utilization': 0.0078125, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 850640.3324799999, 'storage_access_energy': 850640.3324799999, 'read_energy': 850640.3324799999, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([3.24493535,        nan, 0.        ]), 'actual_reads_per_instance': array([65536,     0,     0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([65536,     0,     0]), 'instances': array([4., 4., 0.]), 'utilization': 0.005208333333333333, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 146470.33856, 'storage_access_energy': 146470.33856, 'read_energy': 146470.33856, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([     0, 131072,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([     0, 131072,      0]), 'instances': array([0., 4., 0.]), 'utilization': 0.125, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# ['timeloop-mapper', '/home/workspace/2022.micro.artifact/experiments-richard/arch.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input1.0_weight1.0.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml', '/home/workspace/2022.micro.artifact/experiments-richard/mapper.yaml', '--ERT', 'ERT.yaml', '--ART', 'ART.yaml', '-o', 'timeloop_temp']
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Warning: BackingStorage: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Warning: weight_spad: adjust representation format word bits from 7 to 8 to avoid storage fragmentation.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 3003
#   Factorization options along problem dimension E = 252
#   Factorization options along problem dimension C = 56
#   Factorization options along problem dimension M = 21
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 889945056
# Mapspace Dimension [LoopPermutation] Size: 24883200000
# Mapspace Dimension [Spatial] Size: 6
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 222486264 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.25 | pJ/Algorithmic-Compute =    3.615 | pJ/Compute =    3.615 | L4[] E32 R256 R4X - L3[I] M4 C2 - L2[W] C4 - L1[O] N1 - L0[I] N1
# [  3] Utilization = 0.12 | pJ/Algorithmic-Compute =    2.755 | pJ/Compute =    2.755 | L4[] C2 E32 R1024 C2Y - L3[I] C2 - L2[W] N1 - L1[O] N1 - L0[I] M4
# [  2] STATEMENT: 10000 invalid mappings (5606 fanout, 4394 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 10000 invalid mappings (5631 fanout, 4369 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 10000 invalid mappings (5636 fanout, 4364 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 10000 invalid mappings (5634 fanout, 4366 capacity) found since the last valid mapping, terminating search.
# 2025-04-26 20:48:55,888 - timeloop_mapper - WARNING - No stats file found
# 2025-04-26 20:48:55,895 - timeloop_mapper - INFO - Best mapping file found
# 2025-04-26 20:48:55,897 - timeloop_mapper - WARNING - No energy reference file found
# Summary stats for best mapping found by mapper:
#   Utilization = 0.25 | pJ/Algorithmic-Compute =    3.615 | pJ/Compute =    3.615
# /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml
# Running Timeloop:
# timeloop-model /home/workspace/2022.micro.artifact/experiments-richard/arch.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparsity_testing/1dconv_input1.0_weight1.0.yaml 1dconv_input1.0_weight1.0/searched_mapping.yaml /home/workspace/2022.micro.artifact/experiments-richard/constraints.yaml /home/workspace/2022.micro.artifact/experiments-richard/sparse_opts.yaml --ERT ERT.yaml --ART ART.yaml -o 1dconv_input1.0_weight1.0
# Timeloop completed successfully.
# <class 'dict'>
# {'MAC': {'energy': 588041.4208, 'utilization': 0.25}, 'reg': {'energy': 150994.944, 'storage_access_energy': 150994.944, 'read_energy': 75497.472, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 262144,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 262144,      0]), 'actual_accesses_per_instance': array([     0, 524288,      0]), 'instances': array([4., 4., 4.]), 'utilization': 0.25, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'psum_spad': {'energy': 1324418.34496, 'storage_access_energy': 1324418.34496, 'read_energy': 662047.4608383686, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([      nan,       nan, 0.6316861]), 'actual_reads_per_instance': array([     0,      0, 262016]), 'actual_updates_per_instance': array([     0,      0, 262144]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([     0,      0, 524160]), 'instances': array([4., 4., 4.]), 'utilization': 0.0078125, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'weight_spad': {'energy': 1434006.3232, 'storage_access_energy': 1434006.3232, 'read_energy': 1434006.3232, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([1.367575,      nan, 0.      ]), 'actual_reads_per_instance': array([262144,      0,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([262144,      0,      0]), 'instances': array([4., 4., 0.]), 'utilization': 0.005208333333333333, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'iact_spad': {'energy': 292940.67712, 'storage_access_energy': 292940.67712, 'read_energy': 292940.67712, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([     0, 262144,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([     0, 262144,      0]), 'instances': array([0., 4., 0.]), 'utilization': 0.125, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}, 'BackingStorage': {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}}
# MAC
#
#
#
# {'energy': 588041.4208, 'utilization': 0.25}
# reg
#
#
#
# {'energy': 150994.944, 'storage_access_energy': 150994.944, 'read_energy': 75497.472, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([  nan, 0.072,   nan]), 'actual_reads_per_instance': array([     0, 262144,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([     0, 262144,      0]), 'actual_accesses_per_instance': array([     0, 524288,      0]), 'instances': array([4., 4., 4.]), 'utilization': 0.25, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# psum_spad
#
#
#
# {'energy': 1324418.34496, 'storage_access_energy': 1324418.34496, 'read_energy': 662047.4608383686, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([      nan,       nan, 0.6316861]), 'actual_reads_per_instance': array([     0,      0, 262016]), 'actual_updates_per_instance': array([     0,      0, 262144]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([     0,      0, 524160]), 'instances': array([4., 4., 4.]), 'utilization': 0.0078125, 'multicast': array([1, 1, 1]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0.5]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# weight_spad
#
#
#
# {'energy': 1434006.3232, 'storage_access_energy': 1434006.3232, 'read_energy': 1434006.3232, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([1.367575,      nan, 0.      ]), 'actual_reads_per_instance': array([262144,      0,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([262144,      0,      0]), 'instances': array([4., 4., 0.]), 'utilization': 0.005208333333333333, 'multicast': array([1, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0.5, 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# iact_spad
#
#
#
# {'energy': 292940.67712, 'storage_access_energy': 292940.67712, 'read_energy': 292940.67712, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0.     , 0.27937, 0.     ]), 'actual_reads_per_instance': array([     0, 262144,      0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([     0, 262144,      0]), 'instances': array([0., 4., 0.]), 'utilization': 0.125, 'multicast': array([0, 1, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0. , 0.5, 0. ]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}
# BackingStorage
#
#
#
# {'energy': 0.0, 'storage_access_energy': 0.0, 'read_energy': 0.0, 'temporal_add_energy': 0.0, 'spatial_add_energy': 0.0, 'address_generation_energy': 0.0, 'network_energy': 0.0, 'energy_per_access_per_instance': array([0., 0., 0.]), 'actual_reads_per_instance': array([0, 0, 0]), 'actual_updates_per_instance': array([0, 0, 0]), 'actual_fills_per_instance': array([0, 0, 0]), 'actual_accesses_per_instance': array([0, 0, 0]), 'instances': array([0., 0., 0.]), 'utilization': 0, 'multicast': array([0, 0, 0]), 'dist_multicast': array([0, 0, 0]), 'num_hops': array([0., 0., 0.]), 'ingresses': 0, 'energy_per_hop_per_instance': array([0., 0., 0.])}

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_energy_stacked_by_experiment(experiments_paths):
    """
    Stack the per-level energy for several Timeloop runs.

    Parameters
    ----------
    experiments_paths : list[str]
        Paths to the *.map+stats.xml* files produced by Timeloop.
        Each path is treated as a separate experiment.
    """
    # ---------------------------------------------------------------
    # 1.  Parse the stats from every experiment
    # ---------------------------------------------------------------
    runs   = []
    levels = None                      # to remember the level order
    for p in experiments_paths:
        out = parse_timeloop_stats(p)["energy_breakdown_pJ"]

        # Save the level order from the *first* experiment and assume
        # every other run has the same set (common for Timeloop output).
        if levels is None:
            levels = list(out.keys())

        runs.append([out[lvl]["energy"] for lvl in levels])

    runs = np.log(np.array(runs))              # shape: (n_experiments, n_levels)

    # ---------------------------------------------------------------
    # 2.  Build the stacked bars
    # ---------------------------------------------------------------
    x      = np.arange(len(experiments_paths))
    width  = 0.6
    bottom = np.zeros(len(experiments_paths))

    fig, ax = plt.subplots(figsize=(12, 6))

    for lvl_idx, lvl_name in enumerate(levels):
        ax.bar(
            x,
            runs[:, lvl_idx],
            width,
            bottom=bottom,
            label=lvl_name,
            # No explicit colour → next colour in Matplotlib cycle
        )
        bottom += runs[:, lvl_idx]

    # ---------------------------------------------------------------
    # 3.  Cosmetics
    # ---------------------------------------------------------------
    ax.set_ylabel("Log Energy (pJ)")
    ax.set_title("Total Energy per Experiment (stacked by memory level)")
    ax.set_xticks(x)
    ax.set_xticklabels(experiments_paths, rotation=90)
    ax.legend(title="Memory Level", bbox_to_anchor=(1.02, 1), loc="upper left")
    ax.grid(axis="y", linestyle="--", alpha=0.6)
    plt.show()

# Example usage ------------------------------------------------------
stats_list = [name.strip(".yaml") + "/timeloop-model.map+stats.xml" for name in names]
plot_energy_stacked_by_experiment(stats_list)
# Out:
# /tmp/ipykernel_1310/1847715865.py:29: RuntimeWarning: divide by zero encountered in log
#   runs = np.log(np.array(runs))              # shape: (n_experiments, n_levels)
